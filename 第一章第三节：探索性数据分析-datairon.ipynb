# %% [markdown]
# **复习：**在前面我们已经学习了Pandas基础，知道利用Pandas读取csv数据的增删查改，今天我们要学习的就是**探索性数据分析**，主要介绍如何利用Pandas进行排序、算术计算以及计算描述函数describe()的使用。

# %% [markdown]
# # 1 第一章：探索性数据分析

# %% [markdown]
# #### 开始之前，导入numpy、pandas包和数据

# %%
#加载所需的库
import numpy as np
import pandas as pd

# %%
#载入之前保存的train_chinese.csv数据，关于泰坦尼克号的任务，我们就使用这个数据
df = pd.read_csv('train_chinese.csv')
df
# Out:
#      乘客ID  是否幸存  仓位等级                                                 姓名  \
# 0       1     0     3                            Braund, Mr. Owen Harris
# 1       2     1     1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       3     1     3                             Heikkinen, Miss. Laina
# 3       4     1     1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       5     0     3                           Allen, Mr. William Henry
# 5       6     0     3                                   Moran, Mr. James
# 6       7     0     1                            McCarthy, Mr. Timothy J
# 7       8     0     3                     Palsson, Master. Gosta Leonard
# 8       9     1     3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9      10     1     2                Nasser, Mrs. Nicholas (Adele Achem)
# 10     11     1     3                    Sandstrom, Miss. Marguerite Rut
# 11     12     1     1                           Bonnell, Miss. Elizabeth
# 12     13     0     3                     Saundercock, Mr. William Henry
# 13     14     0     3                        Andersson, Mr. Anders Johan
# 14     15     0     3               Vestrom, Miss. Hulda Amanda Adolfina
# 15     16     1     2                   Hewlett, Mrs. (Mary D Kingcome)
# 16     17     0     3                               Rice, Master. Eugene
# 17     18     1     2                       Williams, Mr. Charles Eugene
# 18     19     0     3  Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 19     20     1     3                            Masselmani, Mrs. Fatima
# 20     21     0     2                               Fynney, Mr. Joseph J
# 21     22     1     2                              Beesley, Mr. Lawrence
# 22     23     1     3                        McGowan, Miss. Anna "Annie"
# 23     24     1     1                       Sloper, Mr. William Thompson
# 24     25     0     3                      Palsson, Miss. Torborg Danira
# 25     26     1     3  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# 26     27     0     3                            Emir, Mr. Farred Chehab
# 27     28     0     1                     Fortune, Mr. Charles Alexander
# 28     29     1     3                      O'Dwyer, Miss. Ellen "Nellie"
# 29     30     0     3                                Todoroff, Mr. Lalio
# ..    ...   ...   ...                                                ...
# 861   862     0     2                        Giles, Mr. Frederick Edward
# 862   863     1     1  Swift, Mrs. Frederick Joel (Margaret Welles Ba...
# 863   864     0     3                  Sage, Miss. Dorothy Edith "Dolly"
# 864   865     0     2                             Gill, Mr. John William
# 865   866     1     2                           Bystrom, Mrs. (Karolina)
# 866   867     1     2                       Duran y More, Miss. Asuncion
# 867   868     0     1               Roebling, Mr. Washington Augustus II
# 868   869     0     3                        van Melkebeke, Mr. Philemon
# 869   870     1     3                    Johnson, Master. Harold Theodor
# 870   871     0     3                                  Balkic, Mr. Cerin
# 871   872     1     1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 872   873     0     1                           Carlsson, Mr. Frans Olof
# 873   874     0     3                        Vander Cruyssen, Mr. Victor
# 874   875     1     2              Abelson, Mrs. Samuel (Hannah Wizosky)
# 875   876     1     3                   Najib, Miss. Adele Kiamie "Jane"
# 876   877     0     3                      Gustafsson, Mr. Alfred Ossian
# 877   878     0     3                               Petroff, Mr. Nedelio
# 878   879     0     3                                 Laleff, Mr. Kristo
# 879   880     1     1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 880   881     1     2       Shelley, Mrs. William (Imanita Parrish Hall)
# 881   882     0     3                                 Markun, Mr. Johann
# 882   883     0     3                       Dahlberg, Miss. Gerda Ulrika
# 883   884     0     2                      Banfield, Mr. Frederick James
# 884   885     0     3                             Sutehall, Mr. Henry Jr
# 885   886     0     3               Rice, Mrs. William (Margaret Norton)
# 886   887     0     2                              Montvila, Rev. Juozas
# 887   888     1     1                       Graham, Miss. Margaret Edith
# 888   889     0     3           Johnston, Miss. Catherine Helen "Carrie"
# 889   890     1     1                              Behr, Mr. Karl Howell
# 890   891     0     3                                Dooley, Mr. Patrick
#
#          性别    年龄  兄弟姐妹个数  父母子女个数              船票信息        票价           客舱  \
# 0      male  22.0       1       0         A/5 21171    7.2500          NaN
# 1    female  38.0       1       0          PC 17599   71.2833          C85
# 2    female  26.0       0       0  STON/O2. 3101282    7.9250          NaN
# 3    female  35.0       1       0            113803   53.1000         C123
# 4      male  35.0       0       0            373450    8.0500          NaN
# 5      male   NaN       0       0            330877    8.4583          NaN
# 6      male  54.0       0       0             17463   51.8625          E46
# 7      male   2.0       3       1            349909   21.0750          NaN
# 8    female  27.0       0       2            347742   11.1333          NaN
# 9    female  14.0       1       0            237736   30.0708          NaN
# 10   female   4.0       1       1           PP 9549   16.7000           G6
# 11   female  58.0       0       0            113783   26.5500         C103
# 12     male  20.0       0       0         A/5. 2151    8.0500          NaN
# 13     male  39.0       1       5            347082   31.2750          NaN
# 14   female  14.0       0       0            350406    7.8542          NaN
# 15   female  55.0       0       0            248706   16.0000          NaN
# 16     male   2.0       4       1            382652   29.1250          NaN
# 17     male   NaN       0       0            244373   13.0000          NaN
# 18   female  31.0       1       0            345763   18.0000          NaN
# 19   female   NaN       0       0              2649    7.2250          NaN
# 20     male  35.0       0       0            239865   26.0000          NaN
# 21     male  34.0       0       0            248698   13.0000          D56
# 22   female  15.0       0       0            330923    8.0292          NaN
# 23     male  28.0       0       0            113788   35.5000           A6
# 24   female   8.0       3       1            349909   21.0750          NaN
# 25   female  38.0       1       5            347077   31.3875          NaN
# 26     male   NaN       0       0              2631    7.2250          NaN
# 27     male  19.0       3       2             19950  263.0000  C23 C25 C27
# 28   female   NaN       0       0            330959    7.8792          NaN
# 29     male   NaN       0       0            349216    7.8958          NaN
# ..      ...   ...     ...     ...               ...       ...          ...
# 861    male  21.0       1       0             28134   11.5000          NaN
# 862  female  48.0       0       0             17466   25.9292          D17
# 863  female   NaN       8       2          CA. 2343   69.5500          NaN
# 864    male  24.0       0       0            233866   13.0000          NaN
# 865  female  42.0       0       0            236852   13.0000          NaN
# 866  female  27.0       1       0     SC/PARIS 2149   13.8583          NaN
# 867    male  31.0       0       0          PC 17590   50.4958          A24
# 868    male   NaN       0       0            345777    9.5000          NaN
# 869    male   4.0       1       1            347742   11.1333          NaN
# 870    male  26.0       0       0            349248    7.8958          NaN
# 871  female  47.0       1       1             11751   52.5542          D35
# 872    male  33.0       0       0               695    5.0000  B51 B53 B55
# 873    male  47.0       0       0            345765    9.0000          NaN
# 874  female  28.0       1       0         P/PP 3381   24.0000          NaN
# 875  female  15.0       0       0              2667    7.2250          NaN
# 876    male  20.0       0       0              7534    9.8458          NaN
# 877    male  19.0       0       0            349212    7.8958          NaN
# 878    male   NaN       0       0            349217    7.8958          NaN
# 879  female  56.0       0       1             11767   83.1583          C50
# 880  female  25.0       0       1            230433   26.0000          NaN
# 881    male  33.0       0       0            349257    7.8958          NaN
# 882  female  22.0       0       0              7552   10.5167          NaN
# 883    male  28.0       0       0  C.A./SOTON 34068   10.5000          NaN
# 884    male  25.0       0       0   SOTON/OQ 392076    7.0500          NaN
# 885  female  39.0       0       5            382652   29.1250          NaN
# 886    male  27.0       0       0            211536   13.0000          NaN
# 887  female  19.0       0       0            112053   30.0000          B42
# 888  female   NaN       1       2        W./C. 6607   23.4500          NaN
# 889    male  26.0       0       0            111369   30.0000         C148
# 890    male  32.0       0       0            370376    7.7500          NaN
#
#     登船港口
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
# 5      Q
# 6      S
# 7      S
# 8      S
# 9      C
# 10     S
# 11     S
# 12     S
# 13     S
# 14     S
# 15     S
# 16     Q
# 17     S
# 18     S
# 19     C
# 20     S
# 21     S
# 22     Q
# 23     S
# 24     S
# 25     S
# 26     C
# 27     S
# 28     Q
# 29     S
# ..   ...
# 861    S
# 862    S
# 863    S
# 864    S
# 865    S
# 866    C
# 867    S
# 868    S
# 869    S
# 870    S
# 871    S
# 872    S
# 873    S
# 874    C
# 875    C
# 876    S
# 877    S
# 878    S
# 879    C
# 880    S
# 881    S
# 882    S
# 883    S
# 884    S
# 885    Q
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
#
# [891 rows x 12 columns]

# %% [markdown]
# ### 1.6 了解你的数据吗？
# 教材《Python for Data Analysis》第五章

# %% [markdown]
# #### 1.6.1 任务一：利用Pandas对示例数据进行排序，要求升序

# %%
# 具体请看《利用Python进行数据分析》第五章 排序和排名 部分

#自己构建一个都为数字的DataFrame数据

'''
我们举了一个例子
pd.DataFrame() ：创建一个DataFrame对象 
np.arange(8).reshape((2, 4)) : 生成一个二维数组（2*4）,第一列：0，1，2，3 第二列：4，5，6，7
index=[2，1] ：DataFrame 对象的索引列
columns=['d', 'a', 'b', 'c'] ：DataFrame 对象的索引行
'''
frame = pd.DataFrame(np.arange(8).reshape((2, 4)), 
                     index=['2', '1'], 
                     columns=['d', 'a', 'b', 'c'])
frame
# Out:
#    d  a  b  c
# 2  0  1  2  3
# 1  4  5  6  7

# %% [markdown]
# 【代码解析】
#
# pd.DataFrame() ：创建一个DataFrame对象
#
# np.arange(8).reshape((2, 4)) : 生成一个二维数组（2*4）,第一列：0，1，2，3 第二列：4，5，6，7
#
# index=['2, 1] ：DataFrame 对象的索引列
#
# columns=['d', 'a', 'b', 'c'] ：DataFrame 对象的索引行

# %% [markdown]
# 【问题】：大多数时候我们都是想根据列的值来排序,所以将你构建的DataFrame中的数据根据某一列，升序排列

# %%
frame.sort_values(by='b', ascending=True)
# Out:
#    d  a  b  c
# 2  0  1  2  3
# 1  4  5  6  7

# %% [raw]
# #回答代码
# frame.sort_values(by='a', ascending=true)

# %% [markdown]
# 【思考】通过书本你能说出Pandas对DataFrame数据的其他排序方式吗？

# %% [markdown]
# 【总结】下面将不同的排序方式做一个总结

# %% [markdown]
# 1.让行索引升序排序

# %%
#代码
frame.sort_index()
# Out:
#    d  a  b  c
# 1  4  5  6  7
# 2  0  1  2  3

# %% [markdown]
# 2.让列索引升序排序

# %%
#代码
frame.sort_index(axis=1)
# Out:
#    a  b  c  d
# 2  1  2  3  0
# 1  5  6  7  4

# %% [markdown]
# 3.让列索引降序排序

# %%
#代码
frame.sort_index(axis=1, ascending=False)
# Out:
#    d  c  b  a
# 2  0  3  2  1
# 1  4  7  6  5

# %% [markdown]
# 4.让任选两列数据同时降序排序

# %%
#代码
frame.sort_values(by=['b', 'c'], ascending=False)
# Out:
#    d  a  b  c
# 1  4  5  6  7
# 2  0  1  2  3

# %% [markdown]
# #### 1.6.2 任务二：对泰坦尼克号数据（trian.csv）按票价和年龄两列进行综合排序（降序排列），从这个数据中你可以分析出什么？

# %%
'''
在开始我们已经导入了train_chinese.csv数据，而且前面我们也学习了导入数据过程，根据上面学习，我们直接对目标列进行排序即可
head(20) : 读取前20条数据

'''

# %%
#代码
df.sort_values(by=['票价', '年龄'],)
# Out:
#      乘客ID  是否幸存  仓位等级                                                 姓名  \
# 302   303     0     3                    Johnson, Mr. William Cahoone Jr
# 271   272     1     3                       Tornquist, Mr. William Henry
# 179   180     0     3                                Leonard, Mr. Lionel
# 822   823     0     1                    Reuchlin, Jonkheer. John George
# 806   807     0     1                             Andrews, Mr. Thomas Jr
# 263   264     0     1                              Harrison, Mr. William
# 597   598     0     3                                Johnson, Mr. Alfred
# 277   278     0     2                        Parkes, Mr. Francis "Frank"
# 413   414     0     2                     Cunningham, Mr. Alfred Fleming
# 466   467     0     2                              Campbell, Mr. William
# 481   482     0     2                   Frost, Mr. Anthony Wood "Archie"
# 633   634     0     1                      Parr, Mr. William Henry Marsh
# 674   675     0     2                         Watson, Mr. Ennis Hastings
# 732   733     0     2                               Knight, Mr. Robert J
# 815   816     0     1                                   Fry, Mr. Richard
# 378   379     0     3                                Betros, Mr. Tannous
# 872   873     0     1                           Carlsson, Mr. Frans Olof
# 326   327     0     3                          Nysveen, Mr. Johan Hansen
# 843   844     0     3                         Lemberopolous, Mr. Peter L
# 818   819     0     3                   Holm, Mr. John Fredrik Alexander
# 371   372     0     3                          Wiklund, Mr. Jakob Alfred
# 202   203     0     3                         Johanson, Mr. Jakob Alfred
# 654   655     0     3                       Hegarty, Miss. Hanora "Nora"
# 143   144     0     3                                Burke, Mr. Jeremiah
# 411   412     0     3                                    Hart, Mr. Henry
# 825   826     0     3                                    Flynn, Mr. John
# 804   805     1     3                            Hedman, Mr. Oskar Arvid
# 129   130     0     3                                 Ekstrom, Mr. Johan
# 477   478     0     3                          Braund, Mr. Lewis Richard
# 131   132     0     3                     Coelho, Mr. Domingos Fernandeo
# ..    ...   ...   ...                                                ...
# 31     32     1     1     Spencer, Mrs. William Augustus (Marie Eugenie)
# 305   306     1     1                     Allison, Master. Hudson Trevor
# 297   298     0     1                       Allison, Miss. Helen Loraine
# 708   709     1     1                               Cleaver, Miss. Alice
# 498   499     0     1    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 332   333     0     1                          Graham, Mr. George Edward
# 609   610     1     1                          Shutes, Miss. Elizabeth W
# 268   269     1     1      Graham, Mrs. William Thompson (Edith Junkins)
# 318   319     1     1                           Wick, Miss. Mary Natalie
# 856   857     1     1         Wick, Mrs. George Dennick (Mary Hitchcock)
# 689   690     1     1                  Madill, Miss. Georgette Alexandra
# 730   731     1     1                      Allen, Miss. Elisabeth Walton
# 779   780     1     1  Robert, Mrs. Edward Scott (Elisabeth Walton Mc...
# 377   378     0     1                          Widener, Mr. Harry Elkins
# 527   528     0     1                                 Farthing, Mr. John
# 700   701     1     1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 716   717     1     1                      Endres, Miss. Caroline Louise
# 380   381     1     1                              Bidois, Miss. Rosalie
# 557   558     0     1                                Robbins, Mr. Victor
# 118   119     0     1                           Baxter, Mr. Quigg Edmond
# 299   300     1     1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 311   312     1     1                         Ryerson, Miss. Emily Borie
# 742   743     1     1              Ryerson, Miss. Susan Parker "Suzette"
# 27     28     0     1                     Fortune, Mr. Charles Alexander
# 88     89     1     1                         Fortune, Miss. Mabel Helen
# 341   342     1     1                     Fortune, Miss. Alice Elizabeth
# 438   439     0     1                                  Fortune, Mr. Mark
# 258   259     1     1                                   Ward, Miss. Anna
# 737   738     1     1                             Lesurer, Mr. Gustave J
# 679   680     1     1                 Cardeza, Mr. Thomas Drake Martinez
#
#          性别     年龄  兄弟姐妹个数  父母子女个数                船票信息        票价  \
# 302    male  19.00       0       0                LINE    0.0000
# 271    male  25.00       0       0                LINE    0.0000
# 179    male  36.00       0       0                LINE    0.0000
# 822    male  38.00       0       0               19972    0.0000
# 806    male  39.00       0       0              112050    0.0000
# 263    male  40.00       0       0              112059    0.0000
# 597    male  49.00       0       0                LINE    0.0000
# 277    male    NaN       0       0              239853    0.0000
# 413    male    NaN       0       0              239853    0.0000
# 466    male    NaN       0       0              239853    0.0000
# 481    male    NaN       0       0              239854    0.0000
# 633    male    NaN       0       0              112052    0.0000
# 674    male    NaN       0       0              239856    0.0000
# 732    male    NaN       0       0              239855    0.0000
# 815    male    NaN       0       0              112058    0.0000
# 378    male  20.00       0       0                2648    4.0125
# 872    male  33.00       0       0                 695    5.0000
# 326    male  61.00       0       0              345364    6.2375
# 843    male  34.50       0       0                2683    6.4375
# 818    male  43.00       0       0              C 7075    6.4500
# 371    male  18.00       1       0             3101267    6.4958
# 202    male  34.00       0       0             3101264    6.4958
# 654  female  18.00       0       0              365226    6.7500
# 143    male  19.00       0       0              365222    6.7500
# 411    male    NaN       0       0              394140    6.8583
# 825    male    NaN       0       0              368323    6.9500
# 804    male  27.00       0       0              347089    6.9750
# 129    male  45.00       0       0              347061    6.9750
# 477    male  29.00       1       0                3460    7.0458
# 131    male  20.00       0       0  SOTON/O.Q. 3101307    7.0500
# ..      ...    ...     ...     ...                 ...       ...
# 31   female    NaN       1       0            PC 17569  146.5208
# 305    male   0.92       1       2              113781  151.5500
# 297  female   2.00       1       2              113781  151.5500
# 708  female  22.00       0       0              113781  151.5500
# 498  female  25.00       1       2              113781  151.5500
# 332    male  38.00       0       1            PC 17582  153.4625
# 609  female  40.00       0       0            PC 17582  153.4625
# 268  female  58.00       0       1            PC 17582  153.4625
# 318  female  31.00       0       2               36928  164.8667
# 856  female  45.00       1       1               36928  164.8667
# 689  female  15.00       0       1               24160  211.3375
# 730  female  29.00       0       0               24160  211.3375
# 779  female  43.00       0       1               24160  211.3375
# 377    male  27.00       0       2              113503  211.5000
# 527    male    NaN       0       0            PC 17483  221.7792
# 700  female  18.00       1       0            PC 17757  227.5250
# 716  female  38.00       0       0            PC 17757  227.5250
# 380  female  42.00       0       0            PC 17757  227.5250
# 557    male    NaN       0       0            PC 17757  227.5250
# 118    male  24.00       0       1            PC 17558  247.5208
# 299  female  50.00       0       1            PC 17558  247.5208
# 311  female  18.00       2       2            PC 17608  262.3750
# 742  female  21.00       2       2            PC 17608  262.3750
# 27     male  19.00       3       2               19950  263.0000
# 88   female  23.00       3       2               19950  263.0000
# 341  female  24.00       3       2               19950  263.0000
# 438    male  64.00       1       4               19950  263.0000
# 258  female  35.00       0       0            PC 17755  512.3292
# 737    male  35.00       0       0            PC 17755  512.3292
# 679    male  36.00       0       1            PC 17755  512.3292
#
#                   客舱 登船港口
# 302              NaN    S
# 271              NaN    S
# 179              NaN    S
# 822              NaN    S
# 806              A36    S
# 263              B94    S
# 597              NaN    S
# 277              NaN    S
# 413              NaN    S
# 466              NaN    S
# 481              NaN    S
# 633              NaN    S
# 674              NaN    S
# 732              NaN    S
# 815             B102    S
# 378              NaN    C
# 872      B51 B53 B55    S
# 326              NaN    S
# 843              NaN    C
# 818              NaN    S
# 371              NaN    S
# 202              NaN    S
# 654              NaN    Q
# 143              NaN    Q
# 411              NaN    Q
# 825              NaN    Q
# 804              NaN    S
# 129              NaN    S
# 477              NaN    S
# 131              NaN    S
# ..               ...  ...
# 31               B78    C
# 305          C22 C26    S
# 297          C22 C26    S
# 708              NaN    S
# 498          C22 C26    S
# 332              C91    S
# 609             C125    S
# 268             C125    S
# 318               C7    S
# 856              NaN    S
# 689               B5    S
# 730               B5    S
# 779               B3    S
# 377              C82    C
# 527              C95    S
# 700          C62 C64    C
# 716              C45    C
# 380              NaN    C
# 557              NaN    C
# 118          B58 B60    C
# 299          B58 B60    C
# 311  B57 B59 B63 B66    C
# 742  B57 B59 B63 B66    C
# 27       C23 C25 C27    S
# 88       C23 C25 C27    S
# 341      C23 C25 C27    S
# 438      C23 C25 C27    S
# 258              NaN    C
# 737             B101    C
# 679      B51 B53 B55    C
#
# [891 rows x 12 columns]

# %% [markdown]
# 【思考】排序后，如果我们仅仅关注年龄和票价两列。根据常识我知道发现票价越高的应该客舱越好，所以我们会明显看出，票价前20的乘客中存活的有14人，这是相当高的一个比例，那么我们后面是不是可以进一步分析一下票价和存活之间的关系，年龄和存活之间的关系呢？当你开始发现数据之间的关系了，数据分析就开始了。
#
# 当然，这只是我的想法，你还可以有更多想法，欢迎写在你的学习笔记中。

# %% [markdown]
# **多做几个数据的排序**

# %%
#代码
df.sort_values(by=['是否幸存', '仓位等级'], ascending=False)
# Out:
#      乘客ID  是否幸存  仓位等级                                                 姓名  \
# 2       3     1     3                             Heikkinen, Miss. Laina
# 8       9     1     3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10     11     1     3                    Sandstrom, Miss. Marguerite Rut
# 19     20     1     3                            Masselmani, Mrs. Fatima
# 22     23     1     3                        McGowan, Miss. Anna "Annie"
# 25     26     1     3  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# 28     29     1     3                      O'Dwyer, Miss. Ellen "Nellie"
# 32     33     1     3                           Glynn, Miss. Mary Agatha
# 36     37     1     3                                   Mamee, Mr. Hanna
# 39     40     1     3                        Nicola-Yarred, Miss. Jamila
# 44     45     1     3                      Devaney, Miss. Margaret Delia
# 47     48     1     3                          O'Driscoll, Miss. Bridget
# 65     66     1     3                           Moubarek, Master. Gerios
# 68     69     1     3                    Andersson, Miss. Erna Alexandra
# 74     75     1     3                                      Bing, Mr. Lee
# 79     80     1     3                           Dowdell, Miss. Elizabeth
# 81     82     1     3                        Sheerlinck, Mr. Jan Baptist
# 82     83     1     3                     McDermott, Miss. Brigdet Delia
# 85     86     1     3  Backstrom, Mrs. Karl Alfred (Maria Mathilda Gu...
# 106   107     1     3                   Salkjelsvik, Miss. Anna Kristine
# 107   108     1     3                             Moss, Mr. Albert Johan
# 109   110     1     3                                Moran, Miss. Bertha
# 125   126     1     3                       Nicola-Yarred, Master. Elias
# 127   128     1     3                          Madsen, Mr. Fridtjof Arne
# 128   129     1     3                                  Peter, Miss. Anna
# 141   142     1     3                           Nysten, Miss. Anna Sofia
# 142   143     1     3  Hakkarainen, Mrs. Pekka Pietari (Elin Matilda ...
# 146   147     1     3       Andersson, Mr. August Edvard ("Wennerstrom")
# 156   157     1     3                   Gilnagh, Miss. Katherine "Katie"
# 165   166     1     3    Goldsmith, Master. Frank John William "Frankie"
# ..    ...   ...   ...                                                ...
# 505   506     0     1         Penasco y Castellana, Mr. Victor de Satode
# 515   516     0     1                       Walker, Mr. William Anderson
# 527   528     0     1                                 Farthing, Mr. John
# 536   537     0     1                  Butt, Major. Archibald Willingham
# 544   545     0     1                         Douglas, Mr. Walter Donald
# 545   546     0     1                       Nicholson, Mr. Arthur Ernest
# 555   556     0     1                                 Wright, Mr. George
# 557   558     0     1                                Robbins, Mr. Victor
# 583   584     0     1                                Ross, Mr. John Hugo
# 602   603     0     1                          Harrington, Mr. Charles H
# 625   626     0     1                              Sutton, Mr. Frederick
# 633   634     0     1                      Parr, Mr. William Henry Marsh
# 659   660     0     1                         Newell, Mr. Arthur Webster
# 662   663     0     1                         Colley, Mr. Edward Pomeroy
# 671   672     0     1                             Davidson, Mr. Thornton
# 694   695     0     1                                    Weir, Col. John
# 698   699     0     1                           Thayer, Mr. John Borland
# 711   712     0     1                                 Klaber, Mr. Herman
# 741   742     0     1                      Cavendish, Mr. Tyrell William
# 745   746     0     1                       Crosby, Capt. Edward Gifford
# 748   749     0     1                          Marvin, Mr. Daniel Warner
# 766   767     0     1                          Brewe, Dr. Arthur Jackson
# 782   783     0     1                             Long, Mr. Milton Clyde
# 789   790     0     1                           Guggenheim, Mr. Benjamin
# 793   794     0     1                           Hoyt, Mr. William Fisher
# 806   807     0     1                             Andrews, Mr. Thomas Jr
# 815   816     0     1                                   Fry, Mr. Richard
# 822   823     0     1                    Reuchlin, Jonkheer. John George
# 867   868     0     1               Roebling, Mr. Washington Augustus II
# 872   873     0     1                           Carlsson, Mr. Frans Olof
#
#          性别    年龄  兄弟姐妹个数  父母子女个数              船票信息        票价           客舱  \
# 2    female  26.0       0       0  STON/O2. 3101282    7.9250          NaN
# 8    female  27.0       0       2            347742   11.1333          NaN
# 10   female   4.0       1       1           PP 9549   16.7000           G6
# 19   female   NaN       0       0              2649    7.2250          NaN
# 22   female  15.0       0       0            330923    8.0292          NaN
# 25   female  38.0       1       5            347077   31.3875          NaN
# 28   female   NaN       0       0            330959    7.8792          NaN
# 32   female   NaN       0       0            335677    7.7500          NaN
# 36     male   NaN       0       0              2677    7.2292          NaN
# 39   female  14.0       1       0              2651   11.2417          NaN
# 44   female  19.0       0       0            330958    7.8792          NaN
# 47   female   NaN       0       0             14311    7.7500          NaN
# 65     male   NaN       1       1              2661   15.2458          NaN
# 68   female  17.0       4       2           3101281    7.9250          NaN
# 74     male  32.0       0       0              1601   56.4958          NaN
# 79   female  30.0       0       0            364516   12.4750          NaN
# 81     male  29.0       0       0            345779    9.5000          NaN
# 82   female   NaN       0       0            330932    7.7875          NaN
# 85   female  33.0       3       0           3101278   15.8500          NaN
# 106  female  21.0       0       0            343120    7.6500          NaN
# 107    male   NaN       0       0            312991    7.7750          NaN
# 109  female   NaN       1       0            371110   24.1500          NaN
# 125    male  12.0       1       0              2651   11.2417          NaN
# 127    male  24.0       0       0           C 17369    7.1417          NaN
# 128  female   NaN       1       1              2668   22.3583        F E69
# 141  female  22.0       0       0            347081    7.7500          NaN
# 142  female  24.0       1       0  STON/O2. 3101279   15.8500          NaN
# 146    male  27.0       0       0            350043    7.7958          NaN
# 156  female  16.0       0       0             35851    7.7333          NaN
# 165    male   9.0       0       2            363291   20.5250          NaN
# ..      ...   ...     ...     ...               ...       ...          ...
# 505    male  18.0       1       0          PC 17758  108.9000          C65
# 515    male  47.0       0       0             36967   34.0208          D46
# 527    male   NaN       0       0          PC 17483  221.7792          C95
# 536    male  45.0       0       0            113050   26.5500          B38
# 544    male  50.0       1       0          PC 17761  106.4250          C86
# 545    male  64.0       0       0               693   26.0000          NaN
# 555    male  62.0       0       0            113807   26.5500          NaN
# 557    male   NaN       0       0          PC 17757  227.5250          NaN
# 583    male  36.0       0       0             13049   40.1250          A10
# 602    male   NaN       0       0            113796   42.4000          NaN
# 625    male  61.0       0       0             36963   32.3208          D50
# 633    male   NaN       0       0            112052    0.0000          NaN
# 659    male  58.0       0       2             35273  113.2750          D48
# 662    male  47.0       0       0              5727   25.5875          E58
# 671    male  31.0       1       0        F.C. 12750   52.0000          B71
# 694    male  60.0       0       0            113800   26.5500          NaN
# 698    male  49.0       1       1             17421  110.8833          C68
# 711    male   NaN       0       0            113028   26.5500         C124
# 741    male  36.0       1       0             19877   78.8500          C46
# 745    male  70.0       1       1         WE/P 5735   71.0000          B22
# 748    male  19.0       1       0            113773   53.1000          D30
# 766    male   NaN       0       0            112379   39.6000          NaN
# 782    male  29.0       0       0            113501   30.0000           D6
# 789    male  46.0       0       0          PC 17593   79.2000      B82 B84
# 793    male   NaN       0       0          PC 17600   30.6958          NaN
# 806    male  39.0       0       0            112050    0.0000          A36
# 815    male   NaN       0       0            112058    0.0000         B102
# 822    male  38.0       0       0             19972    0.0000          NaN
# 867    male  31.0       0       0          PC 17590   50.4958          A24
# 872    male  33.0       0       0               695    5.0000  B51 B53 B55
#
#     登船港口
# 2      S
# 8      S
# 10     S
# 19     C
# 22     Q
# 25     S
# 28     Q
# 32     Q
# 36     C
# 39     C
# 44     Q
# 47     Q
# 65     C
# 68     S
# 74     S
# 79     S
# 81     S
# 82     Q
# 85     S
# 106    S
# 107    S
# 109    Q
# 125    C
# 127    S
# 128    C
# 141    S
# 142    S
# 146    S
# 156    Q
# 165    S
# ..   ...
# 505    C
# 515    S
# 527    S
# 536    S
# 544    C
# 545    S
# 555    S
# 557    C
# 583    C
# 602    S
# 625    S
# 633    S
# 659    C
# 662    S
# 671    S
# 694    S
# 698    C
# 711    S
# 741    S
# 745    S
# 748    S
# 766    C
# 782    S
# 789    C
# 793    C
# 806    S
# 815    S
# 822    S
# 867    S
# 872    S
#
# [891 rows x 12 columns]

# %%
#写下你的思考
仓位等级越高，存活的人数越多

# %% [markdown]
# #### 1.6.3 任务三：利用Pandas进行算术计算，计算两个DataFrame数据相加结果

# %%
# 具体请看《利用Python进行数据分析》第五章 算术运算与数据对齐 部分

#自己构建两个都为数字的DataFrame数据

"""
我们举了一个例子：
frame1_a = pd.DataFrame(np.arange(9.).reshape(3, 3),
                     columns=['a', 'b', 'c'],
                     index=['one', 'two', 'three'])
frame1_b = pd.DataFrame(np.arange(12.).reshape(4, 3),
                     columns=['a', 'e', 'c'],
                     index=['first', 'one', 'two', 'second'])
frame1_a
"""

# %%
#代码
frame1_a = pd.DataFrame(np.arange(9.).reshape(3, 3),
                     columns=['a', 'b', 'c'],
                     index=['one', 'two', 'three'])
frame1_b = pd.DataFrame(np.arange(12.).reshape(4, 3),
                     columns=['a', 'e', 'c'],
                     index=['first', 'one', 'two', 'second'])
frame1_a
# Out:
#          a    b    c
# one    0.0  1.0  2.0
# two    3.0  4.0  5.0
# three  6.0  7.0  8.0

# %% [markdown]
# 将frame_a和frame_b进行相加

# %%
#代码
frame1_a + frame1_b
# Out:
#           a   b     c   e
# first   NaN NaN   NaN NaN
# one     3.0 NaN   7.0 NaN
# second  NaN NaN   NaN NaN
# three   NaN NaN   NaN NaN
# two     9.0 NaN  13.0 NaN

# %% [markdown]
# 【提醒】两个DataFrame相加后，会返回一个新的DataFrame，对应的行和列的值会相加，没有对应的会变成空值NaN。<br>
# 当然，DataFrame还有很多算术运算，如减法，除法等，有兴趣的同学可以看《利用Python进行数据分析》第五章 算术运算与数据对齐 部分，多在网络上查找相关学习资料。

# %% [markdown]
# #### 1.6.4 任务四：通过泰坦尼克号数据如何计算出在船上最大的家族有多少人？

# %%
'''
还是用之前导入的chinese_train.csv如果我们想看看在船上，最大的家族有多少人（‘兄弟姐妹个数’+‘父母子女个数’），我们该怎么做呢？
'''

# %%
#代码
max(df['兄弟姐妹个数'] + df['父母子女个数'])
# Out:
# 10

# %% [markdown]
# 【提醒】我们只需找出”兄弟姐妹个数“和”父母子女个数“之和最大的数，当然你还可以想出很多方法和思考角度，欢迎你来说出你的看法。

# %% [markdown]
# **多做几个数据的相加，看看你能分析出什么？**

# %%
#代码
min(df['兄弟姐妹个数'] + df['父母子女个数'])
# Out:
# 0

# %%
#写下你的其他分析
看最小的家族竟然是0，说明船上有人是没有亲人的

# %% [markdown]
# #### 1.6.5 任务五：学会使用Pandas describe()函数查看数据基本统计信息

# %%
#(1) 关键知识点示例做一遍（简单数据）
# 具体请看《利用Python进行数据分析》第五章 汇总和计算描述统计 部分

#自己构建一个有数字有空值的DataFrame数据


"""
我们举了一个例子：
frame2 = pd.DataFrame([[1.4, np.nan], 
                       [7.1, -4.5],
                       [np.nan, np.nan], 
                       [0.75, -1.3]
                      ], index=['a', 'b', 'c', 'd'], columns=['one', 'two'])
frame2

"""

# %%
#代码
frame2 = pd.DataFrame([[1.4, np.nan], 
                       [7.1, -4.5],
                       [np.nan, np.nan], 
                       [0.75, -1.3]
                      ], index=['a', 'b', 'c', 'd'], columns=['one', 'two'])
frame2
# Out:
#     one  two
# a  1.40  NaN
# b  7.10 -4.5
# c   NaN  NaN
# d  0.75 -1.3

# %% [markdown]
# 调用 describe 函数，观察frame2的数据基本信息

# %%
#代码
frame2.describe()
# Out:
#             one       two
# count  3.000000  2.000000
# mean   3.083333 -2.900000
# std    3.493685  2.262742
# min    0.750000 -4.500000
# 25%    1.075000 -3.700000
# 50%    1.400000 -2.900000
# 75%    4.250000 -2.100000
# max    7.100000 -1.300000

# %% [markdown]
# #### 1.6.6 任务六：分别看看泰坦尼克号数据集中 票价、父母子女 这列数据的基本统计数据，你能发现什么？

# %%
'''
看看泰坦尼克号数据集中 票价 这列数据的基本统计数据
'''

# %%
#代码
df['票价'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: 票价, dtype: float64

# %% [markdown]
# 【思考】从上面数据我们可以看出，试试在下面写出你的看法。然后看看我们给出的答案。
#
# 当然，答案只是我的想法，你还可以有更多想法，欢迎写在你的学习笔记中。

# %% [markdown]
# **多做几个组数据的统计，看看你能分析出什么？**

# %%
# 写下你的其他分析
df['年龄'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: 年龄, dtype: float64

# %% [markdown]
# 【思考】有更多想法，欢迎写在你的学习笔记中。

# %% [markdown]
# 【总结】本节中我们通过Pandas的一些内置函数对数据进行了初步统计查看，这个过程最重要的不是大家得掌握这些函数，而是看懂从这些函数出来的数据，构建自己的数据分析思维，这也是第一章最重要的点，希望大家学完第一章能对数据有个基本认识，了解自己在做什么，为什么这么做，后面的章节我们将开始对数据进行清洗，进一步分析。
