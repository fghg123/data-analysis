# %% [markdown]
# **复习：**数据分析的第一步，加载数据我们已经学习完毕了。当数据展现在我们面前的时候，我们所要做的第一步就是认识他，今天我们要学习的就是**了解字段含义以及初步观察数据**。

# %% [markdown]
# ## 1 第一章：数据载入及初步观察

# %% [markdown]
# ### 1.4 知道你的数据叫什么
# 我们学习pandas的基础操作，那么上一节通过pandas加载之后的数据，其数据类型是什么呢？

# %% [markdown]
# **开始前导入numpy和pandas**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### 1.4.1 任务一：pandas中有两个数据类型DateFrame和Series，通过查找简单了解他们。然后自己写一个关于这两个数据类型的小例子🌰[开放题]

# %%
#写入代码
data=np.random.randn(6,4)#创建一个6行4列的数组
df=pd.DataFrame(data,columns=list('ABCD'),index=[1,2,'a','b','2006-10-1','第六行'])
pd.DataFrame(columns=('id','name','grade','class'))
# Out:
#   File "<ipython-input-5-9c42a2bc49ea>", line 6
#     s = pd.Series([9, 'zheng', 'beijing','Data iron' 128])
#                                                        ^
# SyntaxError: invalid syntax

# %%
s = pd.Series([9, 'zheng', 'beijing','Data iron', 128])

print(s)
# Out:
# 0            9
# 1        zheng
# 2      beijing
# 3    Data iron
# 4          128
# dtype: object

# %%
'''
#我们举的例子
sdata = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}
example_1 = pd.Series(sdata)
example_1
'''

# %%
'''
#我们举的例子
data = {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
        'year': [2000, 2001, 2002, 2001, 2002, 2003],'pop': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}
example_2 = pd.DataFrame(data)
example_2
'''

# %% [markdown]
# #### 1.4.2 任务二：根据上节课的方法载入"train.csv"文件

# %%
#写入代码
df = pd.read_csv('train.csv')

# %% [markdown]
# 也可以加载上一节课保存的"train_chinese.csv"文件。通过翻译版train_chinese.csv熟悉了这个数据集，然后我们对trian.csv来进行操作
# #### 1.4.3 任务三：查看DataFrame数据的每列的项

# %%
#写入代码
df = pd.read_csv('train.csv',engine='python')
print(df.dtypes)
print('-----')
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object
# -----

# %% [markdown]
# #### 1.4.4任务四：查看"cabin"这列的所有项 [有多种方法]

# %%
#写入代码
print(df.Cabin.head(3))
# Out:
# 0    NaN
# 1    C85
# 2    NaN
# Name: Cabin, dtype: object

# %%
#写入代码
print(df['Cabin'].head(100))
# Out:
# 0             NaN
# 1             C85
# 2             NaN
# 3            C123
# 4             NaN
# 5             NaN
# 6             E46
# 7             NaN
# 8             NaN
# 9             NaN
# 10             G6
# 11           C103
# 12            NaN
# 13            NaN
# 14            NaN
# 15            NaN
# 16            NaN
# 17            NaN
# 18            NaN
# 19            NaN
# 20            NaN
# 21            D56
# 22            NaN
# 23             A6
# 24            NaN
# 25            NaN
# 26            NaN
# 27    C23 C25 C27
# 28            NaN
# 29            NaN
#          ...
# 70            NaN
# 71            NaN
# 72            NaN
# 73            NaN
# 74            NaN
# 75          F G73
# 76            NaN
# 77            NaN
# 78            NaN
# 79            NaN
# 80            NaN
# 81            NaN
# 82            NaN
# 83            NaN
# 84            NaN
# 85            NaN
# 86            NaN
# 87            NaN
# 88    C23 C25 C27
# 89            NaN
# 90            NaN
# 91            NaN
# 92            E31
# 93            NaN
# 94            NaN
# 95            NaN
# 96             A5
# 97        D10 D12
# 98            NaN
# 99            NaN
# Name: Cabin, Length: 100, dtype: object

# %% [markdown]
# #### 1.4.5 任务五：加载文件"test_1.csv"，然后对比"train.csv"，看看有哪些多出的列，然后将多出的列删除
# 经过我们的观察发现一个测试集test_1.csv有一列是多余的，我们需要将这个多余的列删去

# %%
#写入代码
df2 = pd.read_csv('test_1.csv',engine='python')
print(df2.dtypes)
# Out:
# Unnamed: 0       int64
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# a                int64
# dtype: object

# %%
#写入代码
del df2['a']

print(df2.dtypes)
# Out:
# Unnamed: 0       int64
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# 【思考】还有其他的删除多余的列的方式吗？

# %%
# 思考回答

df2.drop(['a'], axis=1)

# %% [markdown]
# #### 1.4.6 任务六： 将['PassengerId','Name','Age','Ticket']这几个列元素隐藏，只观察其他几个列元素

# %%
#写入代码
df.drop(['PassengerId','Name','Age','Ticket'],axis=1).head(3)
# Out:
#    Unnamed: 0  Survived  Pclass     Sex  SibSp  Parch     Fare Cabin Embarked  \
# 0           0         0       3    male      1      0   7.2500   NaN        S
# 1           1         1       1  female      1      0  71.2833   C85        C
# 2           2         1       3  female      0      0   7.9250   NaN        S
#
#      a
# 0  100
# 1  100
# 2  100

# %% [markdown]
# 【思考】对比任务五和任务六，是不是使用了不一样的方法(函数)，如果使用一样的函数如何完成上面的不同的要求呢？

# %% [markdown]
# 【思考回答】
#
# 如果想要完全的删除你的数据结构，使用inplace=True，因为使用inplace就将原数据覆盖了，所以这里没有用

# %% [markdown]
# ### 1.5 筛选的逻辑

# %% [markdown]
# 表格数据中，最重要的一个功能就是要具有可筛选的能力，选出我所需要的信息，丢弃无用的信息。
#
# 下面我们还是用实战来学习pandas这个功能。

# %% [markdown]
# #### 1.5.1 任务一： 我们以"Age"为筛选条件，显示年龄在10岁以下的乘客信息。

# %%
#写入代码
df[df["Age"]<10]
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 7             7            8         0       3
# 10           10           11         1       3
# 16           16           17         0       3
# 24           24           25         0       3
# 43           43           44         1       2
# 50           50           51         0       3
# 58           58           59         1       2
# 63           63           64         0       3
# 78           78           79         1       2
# 119         119          120         0       3
# 147         147          148         0       3
# 164         164          165         0       3
# 165         165          166         1       3
# 171         171          172         0       3
# 172         172          173         1       3
# 182         182          183         0       3
# 183         183          184         1       2
# 184         184          185         1       3
# 193         193          194         1       2
# 205         205          206         0       3
# 233         233          234         1       3
# 237         237          238         1       2
# 261         261          262         1       3
# 278         278          279         0       3
# 297         297          298         0       1
# 305         305          306         1       1
# 340         340          341         1       2
# 348         348          349         1       3
# 374         374          375         0       3
# 381         381          382         1       3
# ..          ...          ...       ...     ...
# 445         445          446         1       1
# 448         448          449         1       3
# 469         469          470         1       3
# 479         479          480         1       3
# 480         480          481         0       3
# 489         489          490         1       3
# 530         530          531         1       2
# 535         535          536         1       2
# 541         541          542         0       3
# 549         549          550         1       2
# 618         618          619         1       2
# 634         634          635         0       3
# 642         642          643         0       3
# 644         644          645         1       3
# 691         691          692         1       3
# 720         720          721         1       2
# 750         750          751         1       2
# 751         751          752         1       3
# 755         755          756         1       2
# 777         777          778         1       3
# 787         787          788         0       3
# 788         788          789         1       3
# 803         803          804         1       3
# 813         813          814         0       3
# 824         824          825         0       3
# 827         827          828         1       2
# 831         831          832         1       2
# 850         850          851         0       3
# 852         852          853         0       3
# 869         869          870         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 7                     Palsson, Master. Gosta Leonard    male  2.00      3
# 10                   Sandstrom, Miss. Marguerite Rut  female  4.00      1
# 16                              Rice, Master. Eugene    male  2.00      4
# 24                     Palsson, Miss. Torborg Danira  female  8.00      3
# 43          Laroche, Miss. Simonne Marie Anne Andree  female  3.00      1
# 50                        Panula, Master. Juha Niilo    male  7.00      4
# 58                      West, Miss. Constance Mirium  female  5.00      1
# 63                             Skoog, Master. Harald    male  4.00      3
# 78                     Caldwell, Master. Alden Gates    male  0.83      0
# 119                Andersson, Miss. Ellis Anna Maria  female  2.00      4
# 147                 Ford, Miss. Robina Maggie "Ruby"  female  9.00      2
# 164                     Panula, Master. Eino Viljami    male  1.00      4
# 165  Goldsmith, Master. Frank John William "Frankie"    male  9.00      0
# 171                             Rice, Master. Arthur    male  4.00      4
# 172                     Johnson, Miss. Eleanor Ileen  female  1.00      1
# 182            Asplund, Master. Clarence Gustaf Hugo    male  9.00      4
# 183                        Becker, Master. Richard F    male  1.00      2
# 184              Kink-Heilmann, Miss. Luise Gretchen  female  4.00      0
# 193                       Navratil, Master. Michel M    male  3.00      1
# 205                       Strom, Miss. Telma Matilda  female  2.00      0
# 233                   Asplund, Miss. Lillian Gertrud  female  5.00      4
# 237                 Collyer, Miss. Marjorie "Lottie"  female  8.00      0
# 261                Asplund, Master. Edvin Rojj Felix    male  3.00      4
# 278                               Rice, Master. Eric    male  7.00      4
# 297                     Allison, Miss. Helen Loraine  female  2.00      1
# 305                   Allison, Master. Hudson Trevor    male  0.92      1
# 340                   Navratil, Master. Edmond Roger    male  2.00      1
# 348           Coutts, Master. William Loch "William"    male  3.00      1
# 374                       Palsson, Miss. Stina Viola  female  3.00      3
# 381                      Nakid, Miss. Maria ("Mary")  female  1.00      0
# ..                                               ...     ...   ...    ...
# 445                        Dodge, Master. Washington    male  4.00      0
# 448                   Baclini, Miss. Marie Catherine  female  5.00      2
# 469                    Baclini, Miss. Helene Barbara  female  0.75      2
# 479                         Hirvonen, Miss. Hildur E  female  2.00      0
# 480                   Goodwin, Master. Harold Victor    male  9.00      5
# 489            Coutts, Master. Eden Leslie "Neville"    male  9.00      1
# 530                         Quick, Miss. Phyllis May  female  2.00      1
# 535                           Hart, Miss. Eva Miriam  female  7.00      0
# 541             Andersson, Miss. Ingeborg Constanzia  female  9.00      4
# 549                   Davies, Master. John Morgan Jr    male  8.00      1
# 618                      Becker, Miss. Marion Louise  female  4.00      2
# 634                               Skoog, Miss. Mabel  female  9.00      3
# 642                    Skoog, Miss. Margit Elizabeth  female  2.00      3
# 644                           Baclini, Miss. Eugenie  female  0.75      2
# 691                               Karun, Miss. Manca  female  4.00      0
# 720                Harper, Miss. Annie Jessie "Nina"  female  6.00      0
# 750                                Wells, Miss. Joan  female  4.00      1
# 751                              Moor, Master. Meier    male  6.00      0
# 755                        Hamalainen, Master. Viljo    male  0.67      1
# 777                    Emanuel, Miss. Virginia Ethel  female  5.00      0
# 787                        Rice, Master. George Hugh    male  8.00      4
# 788                       Dean, Master. Bertram Vere    male  1.00      1
# 803                  Thomas, Master. Assad Alexander    male  0.42      0
# 813               Andersson, Miss. Ebba Iris Alfrida  female  6.00      4
# 824                     Panula, Master. Urho Abraham    male  2.00      4
# 827                            Mallet, Master. Andre    male  1.00      0
# 831                  Richards, Master. George Sibley    male  0.83      1
# 850          Andersson, Master. Sigvard Harald Elias    male  4.00      4
# 852                          Boulos, Miss. Nourelain  female  9.00      1
# 869                  Johnson, Master. Harold Theodor    male  4.00      1
#
#      Parch           Ticket      Fare    Cabin Embarked    a
# 7        1           349909   21.0750      NaN        S  100
# 10       1          PP 9549   16.7000       G6        S  100
# 16       1           382652   29.1250      NaN        Q  100
# 24       1           349909   21.0750      NaN        S  100
# 43       2    SC/Paris 2123   41.5792      NaN        C  100
# 50       1          3101295   39.6875      NaN        S  100
# 58       2       C.A. 34651   27.7500      NaN        S  100
# 63       2           347088   27.9000      NaN        S  100
# 78       2           248738   29.0000      NaN        S  100
# 119      2           347082   31.2750      NaN        S  100
# 147      2       W./C. 6608   34.3750      NaN        S  100
# 164      1          3101295   39.6875      NaN        S  100
# 165      2           363291   20.5250      NaN        S  100
# 171      1           382652   29.1250      NaN        Q  100
# 172      1           347742   11.1333      NaN        S  100
# 182      2           347077   31.3875      NaN        S  100
# 183      1           230136   39.0000       F4        S  100
# 184      2           315153   22.0250      NaN        S  100
# 193      1           230080   26.0000       F2        S  100
# 205      1           347054   10.4625       G6        S  100
# 233      2           347077   31.3875      NaN        S  100
# 237      2       C.A. 31921   26.2500      NaN        S  100
# 261      2           347077   31.3875      NaN        S  100
# 278      1           382652   29.1250      NaN        Q  100
# 297      2           113781  151.5500  C22 C26        S  100
# 305      2           113781  151.5500  C22 C26        S  100
# 340      1           230080   26.0000       F2        S  100
# 348      1       C.A. 37671   15.9000      NaN        S  100
# 374      1           349909   21.0750      NaN        S  100
# 381      2             2653   15.7417      NaN        C  100
# ..     ...              ...       ...      ...      ...  ...
# 445      2            33638   81.8583      A34        S  100
# 448      1             2666   19.2583      NaN        C  100
# 469      1             2666   19.2583      NaN        C  100
# 479      1          3101298   12.2875      NaN        S  100
# 480      2          CA 2144   46.9000      NaN        S  100
# 489      1       C.A. 37671   15.9000      NaN        S  100
# 530      1            26360   26.0000      NaN        S  100
# 535      2     F.C.C. 13529   26.2500      NaN        S  100
# 541      2           347082   31.2750      NaN        S  100
# 549      1       C.A. 33112   36.7500      NaN        S  100
# 618      1           230136   39.0000       F4        S  100
# 634      2           347088   27.9000      NaN        S  100
# 642      2           347088   27.9000      NaN        S  100
# 644      1             2666   19.2583      NaN        C  100
# 691      1           349256   13.4167      NaN        C  100
# 720      1           248727   33.0000      NaN        S  100
# 750      1            29103   23.0000      NaN        S  100
# 751      1           392096   12.4750     E121        S  100
# 755      1           250649   14.5000      NaN        S  100
# 777      0           364516   12.4750      NaN        S  100
# 787      1           382652   29.1250      NaN        Q  100
# 788      2        C.A. 2315   20.5750      NaN        S  100
# 803      1             2625    8.5167      NaN        C  100
# 813      2           347082   31.2750      NaN        S  100
# 824      1          3101295   39.6875      NaN        S  100
# 827      2  S.C./PARIS 2079   37.0042      NaN        C  100
# 831      1            29106   18.7500      NaN        S  100
# 850      2           347082   31.2750      NaN        S  100
# 852      1             2678   15.2458      NaN        C  100
# 869      1           347742   11.1333      NaN        S  100
#
# [62 rows x 14 columns]

# %%
df[df["Age"]<10].head(3)
# Out:
#     Unnamed: 0  PassengerId  Survived  Pclass  \
# 7            7            8         0       3
# 10          10           11         1       3
# 16          16           17         0       3
#
#                                Name     Sex  Age  SibSp  Parch   Ticket  \
# 7    Palsson, Master. Gosta Leonard    male  2.0      3      1   349909
# 10  Sandstrom, Miss. Marguerite Rut  female  4.0      1      1  PP 9549
# 16             Rice, Master. Eugene    male  2.0      4      1   382652
#
#       Fare Cabin Embarked    a
# 7   21.075   NaN        S  100
# 10  16.700    G6        S  100
# 16  29.125   NaN        Q  100

# %% [markdown]
# #### 1.5.2 任务二： 以"Age"为条件，将年龄在10岁以上和50岁以下的乘客信息显示出来，并将这个数据命名为midage

# %%
#写入代码
midage = df[df["Age"]>10& (df["Age"]<50)]
midage.head(100)
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# 6             6            7         0       1
# 7             7            8         0       3
# 8             8            9         1       3
# 9             9           10         1       2
# 10           10           11         1       3
# 11           11           12         1       1
# 12           12           13         0       3
# 13           13           14         0       3
# 14           14           15         0       3
# 15           15           16         1       2
# 16           16           17         0       3
# 18           18           19         0       3
# 20           20           21         0       2
# 21           21           22         1       2
# 22           22           23         1       3
# 23           23           24         1       1
# 24           24           25         0       3
# 25           25           26         1       3
# 27           27           28         0       1
# 30           30           31         0       1
# 33           33           34         0       2
# 34           34           35         0       1
# 35           35           36         0       1
# 37           37           38         0       3
# 38           38           39         0       3
# ..          ...          ...       ...     ...
# 91           91           92         0       3
# 92           92           93         0       1
# 93           93           94         0       3
# 94           94           95         0       3
# 96           96           97         0       1
# 97           97           98         1       1
# 98           98           99         1       2
# 99           99          100         0       2
# 100         100          101         0       3
# 102         102          103         0       1
# 103         103          104         0       3
# 104         104          105         0       3
# 105         105          106         0       3
# 106         106          107         1       3
# 108         108          109         0       3
# 110         110          111         0       1
# 111         111          112         0       3
# 112         112          113         0       3
# 113         113          114         0       3
# 114         114          115         0       3
# 115         115          116         0       3
# 116         116          117         0       3
# 117         117          118         0       2
# 118         118          119         0       1
# 119         119          120         0       3
# 120         120          121         0       2
# 122         122          123         0       2
# 123         123          124         1       2
# 124         124          125         0       1
# 125         125          126         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 12                      Saundercock, Mr. William Henry    male  20.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                                Rice, Master. Eugene    male   2.0      4
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 20                                Fynney, Mr. Joseph J    male  35.0      0
# 21                               Beesley, Mr. Lawrence    male  34.0      0
# 22                         McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 24                       Palsson, Miss. Torborg Danira  female   8.0      3
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# 30                            Uruchurtu, Don. Manuel E    male  40.0      0
# 33                               Wheadon, Mr. Edward H    male  66.0      0
# 34                             Meyer, Mr. Edgar Joseph    male  28.0      1
# 35                      Holverson, Mr. Alexander Oskar    male  42.0      1
# 37                            Cann, Mr. Ernest Charles    male  21.0      0
# 38                  Vander Planke, Miss. Augusta Maria  female  18.0      2
# ..                                                 ...     ...   ...    ...
# 91                          Andreasson, Mr. Paul Edvin    male  20.0      0
# 92                         Chaffee, Mr. Herbert Fuller    male  46.0      1
# 93                             Dean, Mr. Bertram Frank    male  26.0      1
# 94                                   Coxon, Mr. Daniel    male  59.0      0
# 96                           Goldschmidt, Mr. George B    male  71.0      0
# 97                     Greenfield, Mr. William Bertram    male  23.0      0
# 98                Doling, Mrs. John T (Ada Julia Bone)  female  34.0      0
# 99                                   Kantor, Mr. Sinai    male  34.0      1
# 100                            Petranec, Miss. Matilda  female  28.0      0
# 102                          White, Mr. Richard Frasar    male  21.0      0
# 103                         Johansson, Mr. Gustaf Joel    male  33.0      0
# 104                     Gustafsson, Mr. Anders Vilhelm    male  37.0      2
# 105                              Mionoff, Mr. Stoytcho    male  28.0      0
# 106                   Salkjelsvik, Miss. Anna Kristine  female  21.0      0
# 108                                    Rekic, Mr. Tido    male  38.0      0
# 110                     Porter, Mr. Walter Chamberlain    male  47.0      0
# 111                               Zabour, Miss. Hileni  female  14.5      1
# 112                             Barton, Mr. David John    male  22.0      0
# 113                            Jussila, Miss. Katriina  female  20.0      1
# 114                              Attalah, Miss. Malake  female  17.0      0
# 115                              Pekoniemi, Mr. Edvard    male  21.0      0
# 116                               Connors, Mr. Patrick    male  70.5      0
# 117                    Turpin, Mr. William John Robert    male  29.0      1
# 118                           Baxter, Mr. Quigg Edmond    male  24.0      0
# 119                  Andersson, Miss. Ellis Anna Maria  female   2.0      4
# 120                        Hickman, Mr. Stanley George    male  21.0      2
# 122                               Nasser, Mr. Nicholas    male  32.5      1
# 123                                Webber, Miss. Susan  female  32.5      0
# 124                        White, Mr. Percival Wayland    male  54.0      0
# 125                       Nicola-Yarred, Master. Elias    male  12.0      1
#
#      Parch             Ticket      Fare        Cabin Embarked    a
# 0        0          A/5 21171    7.2500          NaN        S  100
# 1        0           PC 17599   71.2833          C85        C  100
# 2        0   STON/O2. 3101282    7.9250          NaN        S  100
# 3        0             113803   53.1000         C123        S  100
# 4        0             373450    8.0500          NaN        S  100
# 6        0              17463   51.8625          E46        S  100
# 7        1             349909   21.0750          NaN        S  100
# 8        2             347742   11.1333          NaN        S  100
# 9        0             237736   30.0708          NaN        C  100
# 10       1            PP 9549   16.7000           G6        S  100
# 11       0             113783   26.5500         C103        S  100
# 12       0          A/5. 2151    8.0500          NaN        S  100
# 13       5             347082   31.2750          NaN        S  100
# 14       0             350406    7.8542          NaN        S  100
# 15       0             248706   16.0000          NaN        S  100
# 16       1             382652   29.1250          NaN        Q  100
# 18       0             345763   18.0000          NaN        S  100
# 20       0             239865   26.0000          NaN        S  100
# 21       0             248698   13.0000          D56        S  100
# 22       0             330923    8.0292          NaN        Q  100
# 23       0             113788   35.5000           A6        S  100
# 24       1             349909   21.0750          NaN        S  100
# 25       5             347077   31.3875          NaN        S  100
# 27       2              19950  263.0000  C23 C25 C27        S  100
# 30       0           PC 17601   27.7208          NaN        C  100
# 33       0         C.A. 24579   10.5000          NaN        S  100
# 34       0           PC 17604   82.1708          NaN        C  100
# 35       0             113789   52.0000          NaN        S  100
# 37       0         A./5. 2152    8.0500          NaN        S  100
# 38       0             345764   18.0000          NaN        S  100
# ..     ...                ...       ...          ...      ...  ...
# 91       0             347466    7.8542          NaN        S  100
# 92       0        W.E.P. 5734   61.1750          E31        S  100
# 93       2          C.A. 2315   20.5750          NaN        S  100
# 94       0             364500    7.2500          NaN        S  100
# 96       0           PC 17754   34.6542           A5        C  100
# 97       1           PC 17759   63.3583      D10 D12        C  100
# 98       1             231919   23.0000          NaN        S  100
# 99       0             244367   26.0000          NaN        S  100
# 100      0             349245    7.8958          NaN        S  100
# 102      1              35281   77.2875          D26        S  100
# 103      0               7540    8.6542          NaN        S  100
# 104      0            3101276    7.9250          NaN        S  100
# 105      0             349207    7.8958          NaN        S  100
# 106      0             343120    7.6500          NaN        S  100
# 108      0             349249    7.8958          NaN        S  100
# 110      0             110465   52.0000         C110        S  100
# 111      0               2665   14.4542          NaN        C  100
# 112      0             324669    8.0500          NaN        S  100
# 113      0               4136    9.8250          NaN        S  100
# 114      0               2627   14.4583          NaN        C  100
# 115      0  STON/O 2. 3101294    7.9250          NaN        S  100
# 116      0             370369    7.7500          NaN        Q  100
# 117      0              11668   21.0000          NaN        S  100
# 118      1           PC 17558  247.5208      B58 B60        C  100
# 119      2             347082   31.2750          NaN        S  100
# 120      0       S.O.C. 14879   73.5000          NaN        S  100
# 122      0             237736   30.0708          NaN        C  100
# 123      0              27267   13.0000         E101        S  100
# 124      1              35281   77.2875          D26        S  100
# 125      0               2651   11.2417          NaN        C  100
#
# [100 rows x 14 columns]

# %%
midage = df[(df["Age"]>10)& (df["Age"]<50)]
midage.head(3)
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            1         0       3
# 1           1            2         1       1
# 2           2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked    a
# 0      0         A/5 21171   7.2500   NaN        S  100
# 1      0          PC 17599  71.2833   C85        C  100
# 2      0  STON/O2. 3101282   7.9250   NaN        S  100

# %% [markdown]
# 【提示】了解pandas的条件筛选方式以及如何使用交集和并集操作

# %% [markdown]
# #### 1.5.3 任务三：将midage的数据中第100行的"Pclass"和"Sex"的数据显示出来

# %%
#写入代码
midage = midage.reset_index(drop=True)

midage.loc[[100],['Pclass','Sex']]
# Out:
#      Pclass   Sex
# 100       2  male

# %% [markdown]
# 【思考】这个reset_index()函数的作用是什么？如果不用这个函数，下面的任务会出现什么情况？

# %% [markdown]
# #### 1.5.4 任务四：将midage的数据中第100，105，108行的"Pclass"，"Name"和"Sex"的数据显示出来

# %%
#写入代码
midage = midage.reset_index(drop=True)

midage.loc[[100,105,108],['Pclass','Name','Sex']]
# Out:
#      Pclass                               Name   Sex
# 100       2  Byles, Rev. Thomas Roussel Davids  male
# 105       3           Cribb, Mr. John Hatfield  male
# 108       3                    Calic, Mr. Jovo  male

# %% [markdown]
# 【提示】使用pandas提出的简单方式，你可以看看loc方法
#
# 对比整体的数据位置，你有发现什么问题吗？那么如何解决？

# %% [markdown]
# #### 1.5.5 任务五：使用iloc方法将midage的数据中第100，105，108行的"Pclass"，"Name"和"Sex"的数据显示出来

# %%
#写入代码
midage.iloc[[100,105,108],[2,3,4]]
# Out:
#      Survived  Pclass                               Name
# 100         0       2  Byles, Rev. Thomas Roussel Davids
# 105         0       3           Cribb, Mr. John Hatfield
# 108         0       3                    Calic, Mr. Jovo
